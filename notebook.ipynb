# %%
import pydicom
from pydicom.data import get_testdata_files
import matplotlib.pyplot as plt

# %%
# Replace 'path_to_your_dicom_file.dcm' with the path to your DICOM file
filename1 = r'train_images\4003253\702807833\1.dcm'
filename2 = r'train_images\4003253\1054713880\1.dcm'
filename3 = r'train_images\4003253\2448190387\1.dcm'

# Read the DICOM file
ds1 = pydicom.dcmread(filename1)
ds2 = pydicom.dcmread(


fx , ax = plt.subplots(2, 2, figsize=(10, 5))

# Display the image
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
plt.show()
